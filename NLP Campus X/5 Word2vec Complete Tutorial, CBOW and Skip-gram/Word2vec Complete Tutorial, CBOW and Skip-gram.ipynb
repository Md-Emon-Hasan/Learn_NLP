# %%
import gensim
from gensim.models import Word2Vec,keyedvectors

# %%
import gensim.downloader as api

wv = api.load('word2vec-google-news-300')

vec_king = wv['king']

# %%
wv['cricket']
# Out:
# array([-3.67187500e-01, -1.21582031e-01,  2.85156250e-01,  8.15429688e-02,
#         3.19824219e-02, -3.19824219e-02,  1.34765625e-01, -2.73437500e-01,
#         9.46044922e-03, -1.07421875e-01,  2.48046875e-01, -6.05468750e-01,
#         5.02929688e-02,  2.98828125e-01,  9.57031250e-02,  1.39648438e-01,
#        -5.41992188e-02,  2.91015625e-01,  2.85156250e-01,  1.51367188e-01,
#        -2.89062500e-01, -3.46679688e-02,  1.81884766e-02, -3.92578125e-01,
#         2.46093750e-01,  2.51953125e-01, -9.86328125e-02,  3.22265625e-01,
#         4.49218750e-01, -1.36718750e-01, -2.34375000e-01,  4.12597656e-02,
#        -2.15820312e-01,  1.69921875e-01,  2.56347656e-02,  1.50146484e-02,
#        -3.75976562e-02,  6.95800781e-03,  4.00390625e-01,  2.09960938e-01,
#         1.17675781e-01, -4.19921875e-02,  2.34375000e-01,  2.03125000e-01,
#        -1.86523438e-01, -2.46093750e-01,  3.12500000e-01, -2.59765625e-01,
# ...

# %%
wv['man']
# Out:
# array([ 0.32617188,  0.13085938,  0.03466797, -0.08300781,  0.08984375,
#        -0.04125977, -0.19824219,  0.00689697,  0.14355469,  0.0019455 ,
#         0.02880859, -0.25      , -0.08398438, -0.15136719, -0.10205078,
#         0.04077148, -0.09765625,  0.05932617,  0.02978516, -0.10058594,
#        -0.13085938,  0.001297  ,  0.02612305, -0.27148438,  0.06396484,
#        -0.19140625, -0.078125  ,  0.25976562,  0.375     , -0.04541016,
#         0.16210938,  0.13671875, -0.06396484, -0.02062988, -0.09667969,
#         0.25390625,  0.24804688, -0.12695312,  0.07177734,  0.3203125 ,
#         0.03149414, -0.03857422,  0.21191406, -0.00811768,  0.22265625,
#        -0.13476562, -0.07617188,  0.01049805, -0.05175781,  0.03808594,
#        -0.13378906,  0.125     ,  0.0559082 , -0.18261719,  0.08154297,
#        -0.08447266, -0.07763672, -0.04345703,  0.08105469, -0.01092529,
#         0.17480469,  0.30664062, -0.04321289, -0.01416016,  0.09082031,
# ...

# %%
wv['man'].shape
# Out:
# (300,)

# %%
wv['bottle'].shape
# Out:
# (300,)

# %%
wv.most_similar('man')
# Out:
# [('woman', 0.7664012908935547),
#  ('boy', 0.6824871301651001),
#  ('teenager', 0.6586930155754089),
#  ('teenage_girl', 0.6147903203964233),
#  ('girl', 0.5921714305877686),
#  ('suspected_purse_snatcher', 0.571636438369751),
#  ('robber', 0.5585119128227234),
#  ('Robbery_suspect', 0.5584409832954407),
#  ('teen_ager', 0.5549196600914001),
#  ('men', 0.5489763021469116)]

# %%
wv.most_similar('facebook')
# Out:
# [('Facebook', 0.7563533186912537),
#  ('FaceBook', 0.7076998949050903),
#  ('twitter', 0.6988552212715149),
#  ('myspace', 0.6941817998886108),
#  ('Twitter', 0.664244532585144),
#  ('twitter_facebook', 0.6572229862213135),
#  ('Facebook.com', 0.6529868245124817),
#  ('myspace_facebook', 0.6370643973350525),
#  ('facebook_twitter', 0.6367618441581726),
#  ('linkedin', 0.6356592774391174)]

# %%
wv.similarity('man','women')
# Out:
# 0.2883053

# %%
wv.similarity('man','PHP')
# Out:
# -0.032995153

# %%
wv.doesnt_match(['PHP','java','monkey'])
# Out:
# 'monkey'

# %%
vec = wv['king'] - wv['man'] + wv['women']
wv.most_similar([vec])
# Out:
# [('king', 0.6478992700576782),
#  ('queen', 0.535493791103363),
#  ('women', 0.5233659148216248),
#  ('kings', 0.5162314772605896),
#  ('queens', 0.4995364248752594),
#  ('kumaris', 0.49238473176956177),
#  ('princes', 0.46233269572257996),
#  ('monarch', 0.45280295610427856),
#  ('monarchy', 0.4293173849582672),
#  ('kings_princes', 0.42342400550842285)]

# %%
vec = wv['INR'] - wv['India'] + wv['England']
wv.most_similar([vec])
# Out:
# [('INR', 0.6442341208457947),
#  ('GBP', 0.5040826797485352),
#  ('£_##.###m', 0.4540838301181793),
#  ('England', 0.44649264216423035),
#  ('£', 0.43340998888015747),
#  ('Â_£', 0.4307197630405426),
#  ('stg###', 0.4299262464046478),
#  ('£_#.##m', 0.42561301589012146),
#  ('Pounds_Sterling', 0.42512619495391846),
#  ('GBP##', 0.42464491724967957)]

# %% [markdown]
# __Games of thrones Projects__

# %%
import numpy as np
import pandas as pd

# %%
import gensim
import os

from nltk import sent_tokenize
from gensim.utils import simple_preprocess

story = []
for filename in os.listdir('data'):
    
    f = open(os.path.join('data',filename))
    corpus = f.read()
    raw_sent = sent_tokenize(corpus)
    for sent in raw_sent:
        story.append(simple_preprocess(sent))

# %%
len(story)
# Out:
# 145020

# %%
story
# Out:
# [['game',
#   'of',
#   'thrones',
#   'book',
#   'one',
#   'of',
#   'song',
#   'of',
#   'ice',
#   'and',
#   'fire',
#   'by',
#   'george',
#   'martin',
#   'prologue',
#   'we',
#   'should',
#   'start',
#   'back',
#   'gared',
#   'urged',
#   'as',
#   'the',
#   'woods',
#   'began',
#   'to',
#   'grow',
#   'dark',
#   'around',
#   'them'],
#  ['the', 'wildlings', 'are', 'dead'],
#  ['do', 'the', 'dead', 'frighten', 'you'],
#  ['ser',
#   'waymar',
#   'royce',
#   'asked',
#   'with',
#   'just',
#   'the',
#   'hint',
#   'of',
#   'smile'],
#  ['gared', 'did', 'not', 'rise', 'to', 'the', 'bait'],
#  ['he',
#   'was',
#   'an',
#   'old',
#   'man',
#   'past',
#   'fifty',
#   'and',
#   'he',
#   'had',
#   'seen',
#   'the',
#   'lordlings',
#   'come',
#   'and',
#   'go'],
#  ['dead', 'is', 'dead', 'he', 'said'],
#  ['we', 'have', 'no', 'business', 'with', 'the', 'dead'],
#  ['are', 'they', 'dead'],
#  ['royce', 'asked', 'softly'],
# ...

# %%
wv = gensim.models.Word2Vec(
    window=10,
    min_count=2,
)

# %%
wv.build_vocab
# Out:
# <bound method Word2Vec.build_vocab of <gensim.models.word2vec.Word2Vec object at 0x00000220C5D76050>>

# %%
wv.train(story,total_examples=wv.corpus_count,epochs=wv.epochs)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 wv.train(story,total_examples=wv.corpus_count,epochs=wv.epochs)
#
# File c:\Program Files\Python311\Lib\site-packages\gensim\models\word2vec.py:1045, in Word2Vec.train(self, corpus_iterable, corpus_file, total_examples, total_words, epochs, start_alpha, end_alpha, word_count, queue_factor, report_delay, compute_loss, callbacks, **kwargs)
#    1042 self.min_alpha = end_alpha or self.min_alpha
#    1043 self.epochs = epochs
# -> 1045 self._check_training_sanity(epochs=epochs, total_examples=total_examples, total_words=total_words)
#    1046 self._check_corpus_sanity(corpus_iterable=corpus_iterable, corpus_file=corpus_file, passes=epochs)
#    1048 self.add_lifecycle_event(
#    1049     "train",
#    1050     msg=(
#    (...)
#    1054     ),
#    1055 )
#
# ...

# %%
wv.train(story, total_examples=wv.corpus_count, epochs=wv.epochs)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 wv.train(story, total_examples=wv.corpus_count, epochs=wv.epochs)
#
# File c:\Program Files\Python311\Lib\site-packages\gensim\models\word2vec.py:1045, in Word2Vec.train(self, corpus_iterable, corpus_file, total_examples, total_words, epochs, start_alpha, end_alpha, word_count, queue_factor, report_delay, compute_loss, callbacks, **kwargs)
#    1042 self.min_alpha = end_alpha or self.min_alpha
#    1043 self.epochs = epochs
# -> 1045 self._check_training_sanity(epochs=epochs, total_examples=total_examples, total_words=total_words)
#    1046 self._check_corpus_sanity(corpus_iterable=corpus_iterable, corpus_file=corpus_file, passes=epochs)
#    1048 self.add_lifecycle_event(
#    1049     "train",
#    1050     msg=(
#    (...)
#    1054     ),
#    1055 )
#
# ...

# %%
wv.wv.most_similar('daenerys')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 wv.wv.most_similar('daenerys')
#
# File c:\Program Files\Python311\Lib\site-packages\gensim\models\keyedvectors.py:841, in KeyedVectors.most_similar(self, positive, negative, topn, clip_start, clip_end, restrict_vocab, indexer)
#     838         weight[idx] = item[1]
#     840 # compute the weighted average of all keys
# --> 841 mean = self.get_mean_vector(keys, weight, pre_normalize=True, post_normalize=True, ignore_missing=False)
#     842 all_keys = [
#     843     self.get_index(key) for key in keys if isinstance(key, _KEY_TYPES) and self.has_index_for(key)
#     844 ]
#     846 if indexer is not None and isinstance(topn, int):
#
# ...

# %%
model.wv.doesnt_match(['cersei', 'jaime', 'bronn', 'tyrion'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 model.wv.doesnt_match(['cersei', 'jaime', 'bronn', 'tyrion'])
#
# NameError: name 'model' is not defined

# %%
wv.wv['king']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 wv.wv['king']
#
# File c:\Program Files\Python311\Lib\site-packages\gensim\models\keyedvectors.py:403, in KeyedVectors.__getitem__(self, key_or_keys)
#     389 """Get vector representation of `key_or_keys`.
#     390
#     391 Parameters
#    (...)
#     400
#     401 """
#     402 if isinstance(key_or_keys, _KEY_TYPES):
# --> 403     return self.get_vector(key_or_keys)
#     405 return vstack([self.get_vector(key) for key in key_or_keys])
#
# File c:\Program Files\Python311\Lib\site-packages\gensim\models\keyedvectors.py:446, in KeyedVectors.get_vector(self, key, norm)
#     422 def get_vector(self, key, norm=False):
#     423     """Get the key's vector, as a 1D numpy array.
#     424
#     425     Parameters
#    (...)
#     444
#     445     """
# --> 446     index = self.get_index(key)
# ...

# %%
wv.wv.similarity('arya','sansa')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 wv.wv.similarity('arya','sansa')
#
# File c:\Program Files\Python311\Lib\site-packages\gensim\models\keyedvectors.py:1234, in KeyedVectors.similarity(self, w1, w2)
#    1218 def similarity(self, w1, w2):
#    1219     """Compute cosine similarity between two keys.
#    1220
#    1221     Parameters
#    (...)
#    1232
#    1233     """
# -> 1234     return dot(matutils.unitvec(self[w1]), matutils.unitvec(self[w2]))
#
# File c:\Program Files\Python311\Lib\site-packages\gensim\models\keyedvectors.py:403, in KeyedVectors.__getitem__(self, key_or_keys)
#     389 """Get vector representation of `key_or_keys`.
#     390
#     391 Parameters
#    (...)
#     400
#     401 """
#     402 if isinstance(key_or_keys, _KEY_TYPES):
# --> 403     return self.get_vector(key_or_keys)
# ...

# %%
wv.wv.similarity('cersei','sansa')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 wv.wv.similarity('cersei','sansa')
#
# File c:\Program Files\Python311\Lib\site-packages\gensim\models\keyedvectors.py:1234, in KeyedVectors.similarity(self, w1, w2)
#    1218 def similarity(self, w1, w2):
#    1219     """Compute cosine similarity between two keys.
#    1220
#    1221     Parameters
#    (...)
#    1232
#    1233     """
# -> 1234     return dot(matutils.unitvec(self[w1]), matutils.unitvec(self[w2]))
#
# File c:\Program Files\Python311\Lib\site-packages\gensim\models\keyedvectors.py:403, in KeyedVectors.__getitem__(self, key_or_keys)
#     389 """Get vector representation of `key_or_keys`.
#     390
#     391 Parameters
#    (...)
#     400
#     401 """
#     402 if isinstance(key_or_keys, _KEY_TYPES):
# --> 403     return self.get_vector(key_or_keys)
# ...

# %%
wv.wv.similarity('tywin','sansa')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 wv.wv.similarity('tywin','sansa')
#
# File c:\Program Files\Python311\Lib\site-packages\gensim\models\keyedvectors.py:1234, in KeyedVectors.similarity(self, w1, w2)
#    1218 def similarity(self, w1, w2):
#    1219     """Compute cosine similarity between two keys.
#    1220
#    1221     Parameters
#    (...)
#    1232
#    1233     """
# -> 1234     return dot(matutils.unitvec(self[w1]), matutils.unitvec(self[w2]))
#
# File c:\Program Files\Python311\Lib\site-packages\gensim\models\keyedvectors.py:403, in KeyedVectors.__getitem__(self, key_or_keys)
#     389 """Get vector representation of `key_or_keys`.
#     390
#     391 Parameters
#    (...)
#     400
#     401 """
#     402 if isinstance(key_or_keys, _KEY_TYPES):
# --> 403     return self.get_vector(key_or_keys)
# ...

# %%
wv.wv.get_normed_vectors()
# Out:
# array([], shape=(0, 100), dtype=float32)

# %%
y = model.wv.index_to_key
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 y = model.wv.index_to_key
#
# NameError: name 'model' is not defined

# %%
y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 y
#
# NameError: name 'y' is not defined

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=3)

# %%
X = pca.fit_transform(model.wv.get_normed_vectors())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 X = pca.fit_transform(model.wv.get_normed_vectors())
#
# NameError: name 'model' is not defined

# %%
X.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 X.shape
#
# NameError: name 'X' is not defined

# %%
import plotly.express as px
fig = px.scatter_3d(X[200:300],x=0,y=1,z=2, color=y[200:300])
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 import plotly.express as px
#       2 fig = px.scatter_3d(X[200:300],x=0,y=1,z=2, color=y[200:300])
#       3 fig.show()
#
# ModuleNotFoundError: No module named 'plotly'
